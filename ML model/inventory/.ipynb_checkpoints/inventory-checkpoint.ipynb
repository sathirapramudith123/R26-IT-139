# %%
import pandas as pd, numpy as np, warnings; warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import learning_curve, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor
import shap, joblib

# %%
df = pd.read_csv("shop inventory.csv")
df = df.drop(columns=["target_next_month_price"])      # price target, not used for demand
y = df["target_units_sold"]
X = df.drop(columns=["target_units_sold"])

# %%
train_mask = df["iso_year"] < 2024
X_train, X_test = X[train_mask], X[~train_mask]
y_train, y_test = y[train_mask], y[~train_mask]
print("Train:", len(X_train), "| Test (2024-2025):", len(X_test))
# Out:
# Train: 1773 | Test (2024-2025): 692

# %%
cat = ["item", "category"]
num = [c for c in X.columns if c not in cat]
pre = ColumnTransformer([("cat", OneHotEncoder(handle_unknown="ignore"), cat),
                         ("num", SimpleImputer(strategy="median"), num)])
def P(m): return Pipeline([("pre", pre), ("m", m)])

# %%
models = {
 "LinearRegression": P(LinearRegression()),
 "DecisionTree":     P(DecisionTreeRegressor(max_depth=8, random_state=42)),
 "RandomForest":     P(RandomForestRegressor(n_estimators=300, random_state=42)),
 "GradientBoosting": P(GradientBoostingRegressor(random_state=42)),
 "XGBoost":          P(XGBRegressor(n_estimators=400, max_depth=5, learning_rate=0.05,
                       subsample=0.9, random_state=42)),
}

# %%
models = {
 "LinearRegression": P(LinearRegression()),
 "DecisionTree":     P(DecisionTreeRegressor(max_depth=8, random_state=42)),
 "RandomForest":     P(RandomForestRegressor(n_estimators=300, random_state=42)),
 "GradientBoosting": P(GradientBoostingRegressor(random_state=42)),
 "XGBoost":          P(XGBRegressor(n_estimators=400, max_depth=5, learning_rate=0.05,
                       subsample=0.9, random_state=42)),
}
print("5-model comparison")
scores = {}
for name, m in models.items():
    m.fit(X_train, y_train); p = m.predict(X_test)
    r2 = r2_score(y_test, p); mae = mean_absolute_error(y_test, p)
    rmse = mean_squared_error(y_test, p) ** 0.5
    scores[name] = r2
    print(f"  {name:18s} MAE {mae:6.1f} | RMSE {rmse:6.1f} | R2 {r2:.3f}")
best_name = max(scores, key=scores.get)
print("Best model:", best_name)
model = models[best_name]; model.fit(X_train, y_train)
pred = model.predict(X_test)
# Out:
# === 5-model comparison ===
#   LinearRegression   MAE   23.6 | RMSE   31.9 | R2 0.921
#   DecisionTree       MAE   26.6 | RMSE   38.7 | R2 0.884
#   RandomForest       MAE   21.6 | RMSE   29.8 | R2 0.931
#   GradientBoosting   MAE   22.0 | RMSE   30.1 | R2 0.929
#   XGBoost            MAE   21.8 | RMSE   30.1 | R2 0.930
# Best model: RandomForest

# %%
print("\nMAE :", round(mean_absolute_error(y_test, pred), 2), "units")
print("RMSE:", round(mean_squared_error(y_test, pred) ** 0.5, 2))
print("R^2 :", round(r2_score(y_test, pred), 3))
# Out:
# MAE : 21.59 units
# RMSE: 29.8
# R^2 : 0.931

# %%
plt.figure(figsize=(7,4)); bars = plt.bar(scores.keys(), scores.values(), color="#2b6cb0")
for b, v in zip(bars, scores.values()): plt.text(b.get_x()+b.get_width()/2, v+0.004, f"{v:.3f}", ha="center", fontsize=9)
plt.ylim(0.8, 1.0); plt.ylabel("R² (test 2024-2025)"); plt.title("Component 2 — Model accuracy comparison")
plt.xticks(rotation=15); plt.tight_layout(); plt.show()

# %%
sizes, tr, val = learning_curve(model, X, y, cv=KFold(5, shuffle=True, random_state=42), scoring="r2", train_sizes=np.linspace(0.1, 1.0, 8), n_jobs=-1)
plt.figure(figsize=(7,4))
plt.plot(sizes, tr.mean(1),  "o-", label="Training R²",   color="#2b6cb0")
plt.plot(sizes, val.mean(1), "s-", label="Validation R²", color="#e07b39")
plt.fill_between(sizes, val.mean(1)-val.std(1), val.mean(1)+val.std(1), alpha=0.1, color="#e07b39")
plt.xlabel("Training set size"); plt.ylabel("R² score"); plt.ylim(0.7, 1.02)
plt.title("Component 2 — Learning curve (training vs validation)"); plt.legend(); plt.grid(alpha=0.3)
plt.tight_layout(); plt.show()
print("Training R²:", round(tr.mean(1)[-1], 3), "| Validation R²:", round(val.mean(1)[-1], 3))
# Out:
# Training R²: 0.989 | Validation R²: 0.92

# %%
plt.figure(figsize=(6,6)); plt.scatter(y_test, pred, alpha=0.3)
lims = [y_test.min(), y_test.max()]; plt.plot(lims, lims, 'r--')
plt.xlabel("Actual units"); plt.ylabel("Predicted units")
plt.title("Component 2 — Actual vs Predicted"); plt.tight_layout(); plt.show()

# %%
Xt = model.named_steps["pre"].transform(X_test[:1000])
Xt = Xt.toarray() if hasattr(Xt, "toarray") else np.asarray(Xt)
Xt = Xt.astype(float)
feat_names = model.named_steps["pre"].get_feature_names_out()
explainer = shap.TreeExplainer(model.named_steps["m"])
shap_values = explainer.shap_values(Xt)
shap.summary_plot(shap_values, features=Xt, feature_names=feat_names, plot_type="bar", max_display=12)

# %%
joblib.dump(model, "component2_demand_forecast_model.pkl")
print("Saved best model:", best_name)
# Out:
# Saved best model: RandomForest
